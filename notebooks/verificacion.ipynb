# %%
import sys
sys.path.insert(0, r"D:\PROYECTOS_venv\02_PROYECTOS\01_Python\datafutbol_ar")

from scripts.style import COLORS, set_default_style
from scripts.data_loaders import sb_competitions

set_default_style()
print("Paleta:", COLORS)
print("\nCompetencias disponibles:")
print(sb_competitions().head())
# Out:
# Paleta: {'bg': '#0E2A47', 'primary': '#75AADB', 'accent': '#C9A227', 'text': '#FFFFFF', 'bg_alt': '#0A1628', 'primary_dim': '#4A7AA8', 'muted': '#8FA7BC', 'success': '#75AADB', 'danger': '#C9A227', 'neutral': '#FFFFFF'}
#
# Competencias disponibles:
# d:\PROYECTOS_venv\.venv\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# ...
