# %%
from __future__ import annotations

from typing import Optional

import matplotlib.pyplot as plt
from mplsoccer import PyPizza

from scripts.style import (
    BG, PRIMARY, ACCENT, TEXT, MUTED,
    FONT_TITLE, FONT_BODY, FONT_DATA,
    watermark,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import matplotlib.pyplot as plt
#       6 from mplsoccer import PyPizza
# ----> 8 from scripts.style import (
#       9     BG, PRIMARY, ACCENT, TEXT, MUTED,
#      10     FONT_TITLE, FONT_BODY, FONT_DATA,
#      11     watermark,
#      12 )
#
# ModuleNotFoundError: No module named 'scripts.style'
